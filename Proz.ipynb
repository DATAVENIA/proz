# %%
lista= ["Cenoura", "Alface", "Tomate", "Batata"]

def controle_estoque (opcao, lista):
    print("Menu de opções:")
    print("1 - Alterar o nome de um item")
    print("2 - Mostrar todos os elementos de uma lista:")
    print("Digite a opção desejada:")
opcao= input()

#if opcao == '1':
print("digite o nome do produto a ser alterado")
produto= input()
for i in 3:
if(lista[i] == produto):
print("digite o novo nome do produto")
lista[i]= input()
# Out:
#   File "<ipython-input-39-f3b4004103b2>", line 14
#     if(lista[i] == produto):
#     ^
# IndentationError: expected an indented block after 'for' statement on line 13
